# %% [markdown]
# # Name Entity Recognition

# %% [markdown]
# 1. sentence="""The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."""
# 2.
# 3. Person Eg: Krish C Naik
# 4. Place Or Location Eg: India
# 5. Date Eg: September, 24-09-1989
# 6. Time Eg: 4:30pm
# 7. Money Eg: 1 million dollar
# 8. Organization Eg: iNeuron Private Limited
# 9. Percent Eg: 20%, twenty percent
# 10.

# %%
sentence="""The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures."""

# %%
import nltk

# %%
words = nltk.word_tokenize(sentence)

# %%
pos_elements = nltk.pos_tag(words)

# %%
nltk.ne_chunk(pos_elements).draw()
