# %% [markdown]
# # ROADMAP OF NLP
# * Text Preprocessing -> Tokenization , Limitiazation,Stemming, Stopwards (It's basically a cleaning of Input)
# * Text Preprocessing -> Bow , TFIDF, Unigrams, Bigrams. (It's Basically a Input Text to Vector)
# * Text Preprocessing -> Word2wave, AvgWord2Wave. (It's Basically a Input Text to Vector)
# * RNN, LSTM RNN, GRU RNN (It's part of Neural Network i.e Deep Learning)
# * Text Preprocessing -> Word Embedding
# * Transformer
# * BERT

# %% [markdown]
# # Tokenization in NLP
# ## Tokenization is a Simple process where we Converting  paragraph into  sentences.

# %% [markdown]
# ## Topics
# 1. Corpus -> Paragraph
# 2. Document -> Sentence
# 3. Vocabulary -> Unique Words
# 4. Word -> Word

# %% [markdown]
# ### 1. Corpus -> Paragraph
# " My Name is Prashant and I'm Learning Data Science. I also have Interest in Games and Watching Movies Aswell."

# %% [markdown]
# ## 2. Document -> Sentences
# * "My Name is Prashant and I'm Leraning Data Science."
# * "I Also have Interest in Games and Watiching Movies."

# %% [markdown]
# ## 3. Vocabulary -> Unique Words
# * My
# * Name
# * is
# * Prashant
# * and
# * I'm
# * Learning
# * Data
# * Science
# * I
# * Also
# * have
# * Interest
# * in
# * Games
# * Watching
# * Movies
# * We didn't Include another "and" cuz that was already included previous.

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.2 MB/s  0:00:00
# ...
#   WARNING: The script nltk.exe is installed in 'C:\Users\PRASHANT\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
